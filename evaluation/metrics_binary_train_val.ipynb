# %%
import pandas as pd
import torch
import pickle as pkl
import glob
import os

# %% [markdown]
# # BERT Cased

# %%
path = '..\\Metrics_results\\bert-base-cased\\training\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_bert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_bert_cased.append(pkl.load(file))
        
metrics_bert_cased
# Out:
# [{'epoch': 0,
#   'loss': 0.022074485197663307,
#   'auc_roc_macro': 0.847015380859375,
#   'f1 Macro': 0.7283079028129578,
#   'precision_macro': 0.9428887367248535,
#   'recall_macro': 0.5932884812355042}]

# %%
path = '..\\Metrics_results\\bert-base-cased\\validation\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_bert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_bert_cased.append(pkl.load(file))
        
metrics_bert_cased
# Out:
# [[{'epoch': 0,
#    'loss': 0.05384792014956474,
#    'auc_roc_macro': 0.5199999809265137,
#    'f1 Macro': 0.8771929740905762,
#    'precision_macro': 0.78125,
#    'recall_macro': 1.0,
#    'C/ECE': 0.1220245361328125},
#   {'epoch': 0,
#    'loss': 0.01712443120777607,
#    'auc_roc_macro': 0.9502117037773132,
#    'f1 Macro': 0.853042483329773,
#    'precision_macro': 0.9859147667884827,
#    'recall_macro': 0.7517312169075012,
#    'C/ECE': 0.30554595589637756},
#   {'epoch': 0,
#    'loss': 0.013927709311246872,
#    'auc_roc_macro': 0.9561759233474731,
#    'f1 Macro': 0.896598756313324,
#    'precision_macro': 0.9785813093185425,
#    'recall_macro': 0.8272908329963684,
#    'C/ECE': 0.2671283781528473},
#   {'epoch': 0,
#    'loss': 0.014017726294696331,
#    'auc_roc_macro': 0.9553846120834351,
#    'f1 Macro': 0.8941977024078369,
#    'precision_macro': 0.9778247475624084,
#    'recall_macro': 0.8237478733062744,
#    'C/ECE': 0.24925871193408966}]]

# %% [markdown]
# # BERT Uncased

# %%
path = '..\\Metrics_results\\BERT-Base-Uncased\\training\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_bert_uncased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_bert_uncased.append(pkl.load(file))
        
metrics_bert_uncased
# Out:
# [{'epoch': 0,
#   'loss': 0.02172604575753212,
#   'auc_roc_macro': 0.848441481590271,
#   'f1 Macro': 0.7276222705841064,
#   'precision_macro': 0.9434957504272461,
#   'recall_macro': 0.5921396613121033},
#  {'epoch': 1,
#   'loss': 0.018570685759186745,
#   'auc_roc_macro': 0.8897356986999512,
#   'f1 Macro': 0.7555115818977356,
#   'precision_macro': 0.9680414795875549,
#   'recall_macro': 0.6195021867752075},
#  {'epoch': 2,
#   'loss': 0.017629187554121017,
#   'auc_roc_macro': 0.8980821371078491,
#   'f1 Macro': 0.7603887319564819,
#   'precision_macro': 0.972832441329956,
#   'recall_macro': 0.6240999698638916}]

# %%
path = '..\\Metrics_results\\BERT-Base-Uncased\\validation\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_bert_uncased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_bert_uncased.append(pkl.load(file))
        
metrics_bert_uncased
# Out:
# [[{'epoch': 0,
#    'loss': 0.041350461542606354,
#    'auc_roc_macro': 0.44285714626312256,
#    'f1 Macro': 0.8771929740905762,
#    'precision_macro': 0.78125,
#    'recall_macro': 1.0,
#    'C/ECE': 0.2114480584859848},
#   {'epoch': 0,
#    'loss': 0.01450147945433855,
#    'auc_roc_macro': 0.9538407325744629,
#    'f1 Macro': 0.8878871202468872,
#    'precision_macro': 0.9797259569168091,
#    'recall_macro': 0.811790406703949,
#    'C/ECE': 0.2719346880912781},
#   {'epoch': 0,
#    'loss': 0.013970335945487022,
#    'auc_roc_macro': 0.9586547017097473,
#    'f1 Macro': 0.8900101780891418,
#    'precision_macro': 0.982977032661438,
#    'recall_macro': 0.8131089210510254,
#    'C/ECE': 0.2396150827407837},
#   {'epoch': 0,
#    'loss': 0.013321884907782078,
#    'auc_roc_macro': 0.9586268663406372,
#    'f1 Macro': 0.9248461723327637,
#    'precision_macro': 0.9668218493461609,
#    'recall_macro': 0.8863636255264282,
#    'C/ECE': 0.2665749788284302}],
#  [{'epoch': 1,
# ...

# %% [markdown]
# # DistilBERT

# %% [markdown]
# ## Cased

# %%
path = '..\\Metrics_results\\distilbert-base-cased\\training\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_distilbert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_distilbert_cased.append(pkl.load(file))
        
metrics_distilbert_cased
# Out:
# [{'epoch': 0,
#   'loss': 0.018070116639137268,
#   'auc_roc_macro': 0.90251624584198,
#   'f1 Macro': 0.8043009042739868,
#   'precision_macro': 0.9565060138702393,
#   'recall_macro': 0.6938855648040771},
#  {'epoch': 0,
#   'loss': 0.3375297486782074,
#   'auc_roc_macro': 0.889305055141449,
#   'f1 Macro': 0.8290305137634277,
#   'precision_macro': 0.9175313711166382,
#   'recall_macro': 0.756100594997406},
#  {'epoch': 0,
#   'loss': 0.01822514645755291,
#   'auc_roc_macro': 0.8994461894035339,
#   'f1 Macro': 0.8008132576942444,
#   'precision_macro': 0.9547224044799805,
#   'recall_macro': 0.6896379590034485},
#  {'loss': 0.33911022543907166,
#   'auc_roc_macro': 0.8878217935562134,
#   'f1 Macro': 0.828888475894928,
#   'precision_macro': 0.9160553216934204,
#   'recall_macro': 0.7568689584732056},
#  {'epoch': 0,
#   'loss': 0.018146587535738945,
#   'auc_roc_macro': 0.9014757871627808,
#   'f1 Macro': 0.8017873764038086,
#   'precision_macro': 0.9566764831542969,
# ...

# %%
path = '..\\Metrics_results\\distilbert-base-cased\\validation\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_distilbert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_distilbert_cased.append(pkl.load(file))
        
metrics_distilbert_cased
# Out:
# [[{'epoch': 0,
#    'loss': 0.6978846192359924,
#    'auc_roc_macro': 0.5114285945892334,
#    'f1 Macro': 0.375,
#    'precision_macro': 0.8571428656578064,
#    'recall_macro': 0.23999999463558197},
#   {'epoch': 0,
#    'loss': 0.24186500906944275,
#    'auc_roc_macro': 0.9521986842155457,
#    'f1 Macro': 0.9341168403625488,
#    'precision_macro': 0.9394757151603699,
#    'recall_macro': 0.9288187623023987},
#   {'epoch': 0,
#    'loss': 0.22608202695846558,
#    'auc_roc_macro': 0.9596729278564453,
#    'f1 Macro': 0.941224992275238,
#    'precision_macro': 0.929119884967804,
#    'recall_macro': 0.953649640083313},
#   {'epoch': 0,
#    'loss': 0.21272870898246765,
#    'auc_roc_macro': 0.9605590105056763,
#    'f1 Macro': 0.9407041072845459,
#    'precision_macro': 0.9190961718559265,
#    'recall_macro': 0.9633525013923645}],
#  [{'epoch': 0,
#    'loss': 0.03152348846197128,
#    'auc_roc_macro': 0.3628571331501007,
#    'f1 Macro': 0.25806450843811035,
# ...

# %% [markdown]
# ## Uncased

# %%
path = '..\\Metrics_results\\distilbert-base-uncased\\training\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_distilbert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_distilbert_cased.append(pkl.load(file))
        
metrics_distilbert_cased
# Out:
# [{'epoch': 0,
#   'loss': 0.019481008872389793,
#   'auc_roc_macro': 0.8764809370040894,
#   'f1 Macro': 0.7459595799446106,
#   'precision_macro': 0.9592808485031128,
#   'recall_macro': 0.6102536916732788},
#  {'epoch': 0,
#   'loss': 0.01771571673452854,
#   'auc_roc_macro': 0.9062702655792236,
#   'f1 Macro': 0.8085645437240601,
#   'precision_macro': 0.9579100012779236,
#   'recall_macro': 0.6995062232017517},
#  {'epoch': 0,
#   'loss': 0.017675094306468964,
#   'auc_roc_macro': 0.9066234230995178,
#   'f1 Macro': 0.8028075695037842,
#   'precision_macro': 0.9616941213607788,
#   'recall_macro': 0.6889778971672058},
#  {'epoch': 0,
#   'loss': 0.01773843914270401,
#   'auc_roc_macro': 0.9058312177658081,
#   'f1 Macro': 0.8024147152900696,
#   'precision_macro': 0.9611703157424927,
#   'recall_macro': 0.6886680126190186},
#  {'epoch': 0,
#   'loss': 0.01770828850567341,
#   'auc_roc_macro': 0.9059115052223206,
#   'f1 Macro': 0.8076246976852417,
# ...

# %%
path = '..\\Metrics_results\\distilbert-base-uncased\\validation\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_distilbert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_distilbert_cased.append(pkl.load(file))
        
metrics_distilbert_cased
# Out:
# [[{'epoch': 0,
#    'loss': 0.031126221641898155,
#    'auc_roc_macro': 0.662857174873352,
#    'f1 Macro': 0.07692307978868484,
#    'precision_macro': 1.0,
#    'recall_macro': 0.03999999910593033,
#    'ECE': 0.2929188311100006,
#    'CECE': 0.2929188311100006},
#   {'epoch': 0,
#    'loss': 0.015332434326410294,
#    'auc_roc_macro': 0.9500266909599304,
#    'f1 Macro': 0.9263686537742615,
#    'precision_macro': 0.9537164568901062,
#    'recall_macro': 0.9005455374717712,
#    'ECE': 0.24274197220802307,
#    'CECE': 0.24274154007434845},
#   {'epoch': 0,
#    'loss': 0.019893845543265343,
#    'auc_roc_macro': 0.9131655097007751,
#    'f1 Macro': 0.8897655606269836,
#    'precision_macro': 0.9531623721122742,
#    'recall_macro': 0.8342760801315308,
#    'ECE': 0.282926082611084,
#    'CECE': 0.2829265296459198},
#   {'epoch': 0,
#    'loss': 0.024921711534261703,
#    'auc_roc_macro': 0.8020027875900269,
#    'f1 Macro': 0.824699878692627,
# ...

# %% [markdown]
# # RoBERTa

# %%
path = '..\\Metrics_results\\roberta-base\\training\\binary'
extension = '*.pkl'

files = glob.glob(os.path.join(path, extension))

metrics_distilbert_cased = []
for file in files:
    with open(file, 'rb') as file:
        metrics_distilbert_cased.append(pkl.load(file))
        
metrics_distilbert_cased
# Out:
# [{'epoch': 0,
#   'loss': 0.023823164403438568,
#   'auc_roc_macro': 0.8165563344955444,
#   'f1 Macro': 0.706333577632904,
#   'precision_macro': 0.9277464151382446,
#   'recall_macro': 0.5702416300773621},
#  {'epoch': 1,
#   'loss': 0.020066509023308754,
#   'auc_roc_macro': 0.8730971813201904,
#   'f1 Macro': 0.7443946003913879,
#   'precision_macro': 0.9591907262802124,
#   'recall_macro': 0.6081979274749756},
#  {'epoch': 2,
#   'loss': 0.018994957208633423,
#   'auc_roc_macro': 0.8840105533599854,
#   'f1 Macro': 0.7506344318389893,
#   'precision_macro': 0.9654046893119812,
#   'recall_macro': 0.6140326857566833}]

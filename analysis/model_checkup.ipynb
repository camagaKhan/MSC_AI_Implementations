# %%
import pickle

# %%
MODEL_NAME, FILE_NAME, MODE = 'bert-base-cased', 'BERT-Cased-kaiming_128_BCE_jigsaw_6lbls_validation', 'validation'

# %%
with open(f'../Metrics_results/{MODEL_NAME}/{MODE}/{FILE_NAME}.pkl', 'rb') as file:
    data = pickle.load(file)
    
data
# Out:
# [{'epoch': 1,
#   'validation_loss': 0.12301692120442503,
#   'auc_per_class': tensor([0.9527, 0.9715, 0.9856, 0.9732, 0.9566, 0.9775], device='cuda:0'),
#   'auc_roc_macro': 0.9695140719413757,
#   'f1_Micro': 0.7082738876342773,
#   'f1_Macro': 0.595329761505127,
#   'f1_per_class': tensor([0.7363, 0.6369, 0.5402, 0.5047, 0.7114, 0.4425], device='cuda:0'),
#   'precision_macro': 0.5528882145881653,
#   'precision_micro': 0.5938131213188171,
#   'recall_macro': 0.6700847148895264,
#   'recall_micro': 0.8773968815803528,
#   'precision_per_class': tensor([0.6106, 0.6066, 0.4972, 0.4554, 0.5884, 0.5593], device='cuda:0'),
#   'precision_recall_curve': ([tensor([0.2232, 0.2232, 0.2232,  ..., 1.0000, 1.0000, 1.0000], device='cuda:0'),
#     tensor([0.0145, 0.0145, 0.0145,  ..., 1.0000, 1.0000, 1.0000], device='cuda:0'),
#     tensor([0.0069, 0.0069, 0.0069,  ..., 1.0000, 1.0000, 1.0000], device='cuda:0'),
# ...
